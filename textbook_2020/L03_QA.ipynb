# %%
"""
＊重要＊
最初にこのセルを実行してください。
この実習で使うサンプルファイルをダウンロードします。
"""
# サンプルデータ 
# !wget https://raw.githubusercontent.com/CropEvol/lecture/master/data/allele_count_mini2.txt  -O allele_count_mini2.txt

# %% [markdown]
# ---
#
# # Q.
#
# 複数の要素を取り出すときに、print(line, line[4], line[5])とするべきところを、print(line, line[4, 5])としてしまいエラーとなったのですが、複数の要素を取り出す方法は、この「print(line, line[4], line[5])」という１通りなのか疑問に思いました。
#
# # A.
#
# 少し無理やりな方法であればあります。`join()`というリストを文字列化する関数を使う方法です。

# %%
# 例）　join()を使う方法
f = open("allele_count_mini2.txt")

for line in f:
  line = line.split()  # リスト化
  item45 = line[4:6]  # 4番目と5番目の要素を取り出す
  print(item45)      # 確認
  item45 = ' '.join(item45) # join()で要素間に半角スペースを入れた文字列にする
  print(item45)             # 確認


f.close()
