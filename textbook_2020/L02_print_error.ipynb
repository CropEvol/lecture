# %%
# print実行結果（初期状態）
print("AAAAA")

# %%
# 原因：関数名と同じ名前の変数を作成するコードを書いたため
print = len("AAAAA")
print = "AAAAA"

# %%
# print実行結果
print("AAAAA")

# %% [markdown]
# 関数名と同じ名前の変数を作ってしまうと、関数の機能を上書きしてしまう。

# %% [markdown]
# 解決策: ランタイムを再起動
#
# - ヘッダー「ランタイム」 > 「ランタイムを再起動」
