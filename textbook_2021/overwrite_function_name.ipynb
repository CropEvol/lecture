# %% [markdown]
# <img src="https://lh3.googleusercontent.com/pw/AM-JKLVhTn_UySwMdfMwXvoq8l3VN7IkrY9cwtH2YJVMxAlMznUBWC9IpFtgPRIyfAXru4oykkYD-1WjWi0Ao5XgkB9JICvzDBcfn0L_5X2_KOOppsURK5DfSifCC-s7Vx5oQrBUn_BNWn_hfAPdhlVbKQGE=w1097-h235-no?authuser=0" alt="2021年度ゲノム情報解析入門" height="100px" align="middle">
#
# <div align="right"><a href="https://github.com/CropEvol/lecture#section2">実習表ページに戻る</a></div>

# %% [markdown]
# # 関数名の上書きエラーについて

# %% [markdown]
# 　まずは、下のprint関数やlen関数が正常に動くことを確認してください。

# %%
print("ATGC")

# %%
print(len("ATGC"))

# %% [markdown]
# 　次のコードセルを実行すると、関数と同じ名前の変数が作成されます。

# %%
print = "AAAAAAAAA"
len   = "CCCCCCCCCC"

# %% [markdown]
# 　上のコードセルを実行したあと、以下のコードを実行すると、エラーが発生します。

# %%
print("ATGC")

# %%
print(len("ATGC"))

# %% [markdown]
# 　これは、関数と同じ名前の変数を作成すると、元々定義されていた関数名が変数名に上書きされ、関数として使用できなくなるためです。
#
# 　Pythonに標準で定義されている関数（例えば、以下の名前の関数）は多数あります。できるかぎり関数と同じ名前の変数は作らないようにするのがよいでしょう。
# - print
# - len
# - count
# - list
# - dict
# - str
# - int
# - sum
#
# 　変数名を複合語にするなどすれば、関数名を上書きしてしまうことは少なくなるでしょう。
#
# 例:
# - dna_len
# - count_A

# %% [markdown]
# 　もし関数名と同じ変数を作ってしまい、元の状態に戻したい場合は、以下の手順でGoogle Colabを再起動してください。
# ```
# ヘッダーの「ランタイム」 > 「ランタイムを再起動」
# ```

# %% [markdown]
# <div align="right"><a href="https://github.com/CropEvol/lecture#section2">実習表ページに戻る</a></div>
