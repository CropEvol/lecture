# %% [markdown]
# 2019年度「ゲノム情報解析入門」テキスト

# %% [markdown]
# # Google Colaboratoryの使い方 [課題]
#
# 1. 演習1: プログラムを実行する
# 1. 演習2: プログラムを書いて、実行する
# 1. 演習3: テキストを書く
# 1. 演習4: ノートブックを保存する
# 1. 課題の提出方法

# %% [markdown]
# ## 演習1: プログラムを実行する

# %% [markdown]
# ## 演習2: プログラムを書いて、実行する
#
# 　このセルのすぐ下の「コードセル」を作成し、次のプログラムを書いて、実行してください。
#
#
# ```python
# signal = 'red'
# if signal == 'blue':
#   print('GO')
# else:
#   print('STOP!')
#
# ```
# _このプログラムは、条件により異なる処理をするプログラムです。_
# _正常に実行されれば、「STOP!」が表示されます。_

# %% [markdown]
# ## 演習3: テキストを書く
# 　すぐ下の「テキストセル」にこの講義に関して、質問や要望、コメントを書いてください。

# %% [markdown]
# 質問・要望・コメント:

# %% [markdown]
# ## 演習4: ノートブックを保存する
#
# 　このノートブックを保存してください。

# %% [markdown]
# ## 課題の提出方法
# 1. ノートブックをダウンロードする
#   - ダウンロード方法: 「ファイル」 > 「.ipynb をダウンロード」
# 1. メールで課題を提出する
#   - 提出先メールアドレス: cropevol@gmail.com
#   - メール件名: HW[課題番号(2桁)]+SID[学籍番号(4桁-2桁-４桁)]（**すべて半角英数**） にする
#     - 課題番号: 02
#     - 記入例: HW02+1234-56-7890
#   - メール本文: 未入力でも構いません
#   - 添付ファイル: ダウンロードしたノートブックファイル（.ipynb）を添付する
#   - 提出締切:
